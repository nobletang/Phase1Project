# %% [markdown]
# hypothesis
#
# 1. runtime vs gross
#
# 2. higher movie budget = higher gross
#
# 3. directors with more experience have higher gross
#
# 4. type of genre returns higher gross
#     benefits from not having to clean up groups / combos

# %% [markdown]
# further discussion
#
# runtime and popularity / score

# %% [markdown]
# ### eda

# %%
import pandas as pd

# %%
df = pd.read_csv('zippedData/movies.csv', index_col=0)

# %%
df
# Out:
#                                                rating      genre  year  \
# name
# The Shining                                         R      Drama  1980
# The Blue Lagoon                                     R  Adventure  1980
# Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# Airplane!                                          PG     Comedy  1980
# Caddyshack                                          R     Comedy  1980
# ...                                               ...        ...   ...
# More to Life                                      NaN      Drama  2020
# Dream Round                                       NaN     Comedy  2020
# Saving Mbango                                     NaN      Drama  2020
# It's Just Us                                      NaN      Drama  2020
# Tee em el                                         NaN     Horror  2020
#
#                                                                         released  \
# name
# ...

# %% [markdown]
# ### cleaning

# %%
df.dropna(inplace=True)

df.shape
# Out:
# (5421, 14)

# %%
df
# Out:
#                                                    rating      genre  year  \
# name
# The Shining                                             R      Drama  1980
# The Blue Lagoon                                         R  Adventure  1980
# Star Wars: Episode V - The Empire Strikes Back         PG     Action  1980
# Airplane!                                              PG     Comedy  1980
# Caddyshack                                              R     Comedy  1980
# ...                                                   ...        ...   ...
# Bad Boys for Life                                       R     Action  2020
# Sonic the Hedgehog                                     PG     Action  2020
# Dolittle                                               PG  Adventure  2020
# The Call of the Wild                                   PG  Adventure  2020
# The Eight Hundred                               Not Rated     Action  2020
#
# ...

# %%
df = df[['genre', 'director', 'budget', 'gross', 'runtime', 'rating']]
df.shape
# Out:
# (5421, 6)

# %%
df['genre'].value_counts()
# Out:
# Comedy       1496
# Action       1415
# Drama         863
# Crime         399
# Adventure     327
# Biography     311
# Animation     277
# Horror        251
# Fantasy        41
# Mystery        17
# Thriller        7
# Sci-Fi          6
# Romance         5
# Family          4
# Western         2
# Name: genre, dtype: int64

# %%
df[df['runtime'] >= 180]
# Out:
#                                                    genre  \
# name
# Heaven's Gate                                  Adventure
# Reds                                           Biography
# Gandhi                                         Biography
# Fanny and Alexander                                Drama
# The Right Stuff                                Adventure
# Once Upon a Time in America                        Crime
# Dances with Wolves                             Adventure
# JFK                                                Drama
# At Play in the Fields of the Lord                  Drama
# Malcolm X                                      Biography
# Schindler's List                               Biography
# Blood In, Blood Out                                Crime
# Gettysburg                                         Drama
# Wyatt Earp                                     Adventure
# Nixon                                          Biography
# ...

# %%
df['budget'].describe()
# Out:
# count    5.421000e+03
# mean     3.600917e+07
# std      4.157337e+07
# min      6.000000e+03
# 25%      1.000000e+07
# 50%      2.180000e+07
# 75%      4.500000e+07
# max      3.560000e+08
# Name: budget, dtype: float64

# %%
df[df['budget'] <= 2.180000e+07].quantile(.25,)
# Out:
# budget     5000000.0
# gross      4140339.0
# runtime         93.0
# Name: 0.25, dtype: float64

# %%
df['gross'].describe()
# Out:
# count    5.421000e+03
# mean     1.032297e+08
# std      1.873027e+08
# min      3.090000e+02
# 25%      1.073640e+07
# 50%      3.686941e+07
# 75%      1.124625e+08
# max      2.847246e+09
# Name: gross, dtype: float64

# %% [markdown]
# ### visualization

# %% [markdown]
# ### write to csv file and push to github

# %%
df.to_csv(path_or_buf='zippedData/movies_cleaned.csv', index=False)
